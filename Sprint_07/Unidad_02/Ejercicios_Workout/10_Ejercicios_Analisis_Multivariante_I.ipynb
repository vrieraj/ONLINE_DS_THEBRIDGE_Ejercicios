# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el análisis bivariante, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos se subirá a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 0
#
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bootcampviztools import *

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga el dataset de admisiones que conoces de la unidad anterior y que se encuentra en la ruta "./data/admission_data.csv", deshazte de las columnas innecesarias

# %%
df_admission = pd.read_csv('./data/admission_data.csv', usecols=['Major','Gender','Admission'])
df_admission.head()
# Out:
#                      Major Gender Admission
# 0       School of Medicine      F  Rejected
# 1  Department of Economics      M  Accepted
# 2                    Other      F  Accepted
# 3                    Other      M  Accepted
# 4                    Other      M  Rejected

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Haz el análisis bivariante de "Admission" y "Major" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio) y contesta a las siguientes preguntas:
# * ¿Cuál es el departamento con el mayor porcentaje de admisiones?¿Y el de menor?
# *Física y astronomía tiene mayor porcentaje de admisiones, mientras que psicología tan sólo admite a menos de un 1%*
# * ¿Existe alguna diferencia destacada entre los departamentos?
# *También varían en cantidad: mientras que física y astronmía aceptan a 914000 estudiantes, psicología sólo acepta a 47000, rechazando a 667000*

# %%
plot_categorical_relationship_fin(df_admission, 'Major', 'Admission', relative_freq=True, show_values=True, size_group=7, giro=80)
plot_categorical_relationship_fin(df_admission, 'Major', 'Admission', relative_freq=False, show_values=True, size_group=7, giro=80)

# %% [markdown]
# ### Ejercicio 3
#
# Repite el análisis para "Admission" y "Gender" y responde a las siguientes preguntas:
# * ¿Existe una diferencia visual significativa entre el porcentaje de admitidos de cada género?
# *Se aceptan en torno a un 10 % de estudianes más de hombres*
# * ¿Cuál de los dos grupos tiene más admisiones?
# *En datos brutos se aceptan más del doble de estudiantes masculinos*

# %%
plot_categorical_relationship_fin(df_admission, 'Gender', 'Admission', relative_freq=True, show_values=True, giro=0)
plot_categorical_relationship_fin(df_admission, 'Gender', 'Admission', relative_freq=False, show_values=True, giro=0)

# %% [markdown]
# ### Ejercicio 4
#
# Carga el dataset de propinas (tips) que conoces de la unidad anterior y que se encuentra en la ruta "./data/tips.csv", deshazte de las columnas innecesarias

# %%
df_tips = pd.read_csv('./data/tips.csv',index_col=0)
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Ejercicio 5
#
# Haz el análisis bivariante de "tip" y "sex" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio), añade el cálculo de la media y mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguientes preguntas:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "sex"?
# *En los hombres el conteo es mayor, pero la distribución es similar*
# * ¿Son diferentes respecto al  conjunto total?
# *No*

# %%
plot_categorical_relationship_fin(df_tips, 'sex', 'tip', relative_freq=False, show_values=False)

# %%
plot_categorical_numerical_relationship(df_tips, 'sex', 'tip', show_values=True, measure='mean')
plot_categorical_numerical_relationship(df_tips, 'sex', 'tip', show_values=True, measure='median')

# %%
pinta_distribucion_categoricas(df_tips, ['sex'], relativa=True, mostrar_valores=True, giro = 0)

# %%
plot_grouped_histograms(df_tips, 'sex', 'tip', 2)

# %% [markdown]
# ### Ejercicio 6
#
# Repite el análisis pero esta vez para "tip" y "smoker", añade también el cálculo de la media y de la mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguiente pregunta:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "smoker"?
# *No*

# %%
plot_categorical_relationship_fin(df_tips, 'smoker', 'tip', relative_freq=False, show_values=False)
plot_categorical_numerical_relationship(df_tips, 'smoker', 'tip', show_values=True, measure='mean')
plot_categorical_numerical_relationship(df_tips, 'smoker', 'tip', show_values=True, measure='median')

# %% [markdown]
# ### Ejericicio 7
#
# Carga ahora el datase de accidentes de coches, que se encuentra en la ruta "./data/car_crashes.csv" y deshazte de las columnas innecesarias

# %%
df_cars = pd.read_csv('./data/car_crashes.csv', sep='|', index_col=0)
df_cars.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ### Ejercicio 8
#
# Haz un analisis bivairante entre "total" y "speeding". Muestra su diagrama de dispersión y su valor de correlación de pearson obtenido con pandas. Luego contesta a la siguiente pregunta
# * ¿Existe alguna relación visual entre las variables?¿Y numérica?
# *Ligeramente visual, se intuye una línea oblicua ascendente para los valores superiores a igualdad de'total'.*
# *Matemáticamente se confirma con una cierta correlación positiva de 0,61*

# %%
grafico_dispersion_con_correlacion(df_cars, 'total', 'speeding', tamano_puntos=50, mostrar_correlacion=True)

# %% [markdown]
# ### Ejercicio 9
#
# Usa scipy tal como lo hicimos en el workout para hacer el test de correlación. ¿Cuál es el p-value?¿Qué podemos decir de la correlación lineal entre "total" y "speeding"?0
# *0,000001867, por tanto, NO están correlacionadas*

# %%
import numpy as np
from scipy import stats

stats.pearsonr(df_cars['total'], df_cars['speeding'])
# Out:
# PearsonRResult(statistic=np.float64(0.6115476008001185), pvalue=np.float64(1.8670391109056814e-06))
